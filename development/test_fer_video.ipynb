# %%
import os
import sys

import matplotlib
import matplotlib.pyplot as plt

from fer import FER, Video

# %%
if os.name == 'posix' and "DISPLAY" not in os.environ:
    matplotlib.use("Agg")

# %%
# if __name__ == "__main__":
#     try:
#         videofile = sys.argv[1]
#     except:
videofile = "sample/videos/woman.mp4"
detector = FER(mtcnn=True)

video = Video(videofile)

# Output list of dictionaries
raw_data = video.analyze(detector, display=False, frequency=15)

# Convert to pandas for analysis
df = video.to_pandas(raw_data)
df = video.get_first_face(df)
df = video.get_emotions(df)

# Plot emotions
df.plot()
plt.show()
# Out:
# 16-01-2022:11:09:51,974 INFO     [classes.py:199] 29.97 fps, 464 frames, 15.48 seconds
# 16-01-2022:11:09:51,974 INFO     [classes.py:207] Making directories at output
# 16-01-2022:11:09:51,975 INFO     [classes.py:352] Deleted pre-existing output\woman_output.mp4
#   7%|▋         | 31/464 [00:27<06:26,  1.12frames/s]
# 16-01-2022:11:10:19,643 INFO     [classes.py:320] Completed analysis: saved to output\woman_output.mp4
# 16-01-2022:11:10:19,643 INFO     [classes.py:327] Starting to Zip
# 16-01-2022:11:10:19,661 INFO     [classes.py:339] Zip has finished

# %%
import tensorflow as tf
import pandas as pd
import sklearn

# %%
train = pd.read_excel('vicinitas_search_results.xlsx')
train.columns
train = train[train['Language'] == 'en']
train = train[['Text', 'Hashtags', 'Media URLs']]

# %%
train.head()
# Out:
#                                                 Text  Hashtags  \
# 0  RT @ryandp_92 : @KdesterOfficial @lexniel_1921...         0
# 1                 @shiraeis Happy birthday 🎁🎂🎈 Shira         0
# 2  RT @szentandrassym : @PSeabra52 @TeresaR869805...         0
# 3  RT @PetriZinni : @hotdrippinchoco Happy birthd...         0
# 4  RT @urstrulyMahesh : Congratulations team #HER...         1
#
#                                         Media URLs
# 0                                              NaN
# 1                                              NaN
# 2  https://pbs.twimg.com/media/FJIi9A1XsAIrfzY.jpg
# 3                                              NaN
# 4                                              NaN

# %%
train.columns
# Out:
# Index(['Text', 'Language', 'Hashtags', 'Media URLs'], dtype='object')

# %%
train['Media URLs'][2]
# Out:
# 'https://pbs.twimg.com/media/FJIi9A1XsAIrfzY.jpg'

# %%
import fer
import cv2

# %%
img = cv2.imread(train['Media URLs'][2])

# %%
# img = cv2.imread("./sample/images/justin.jpg")
img = cv2.imread(train['Media URLs'][2])
import requests
# img = Image.open(io.BytesIO(requests.get('https://pbs.twimg.com/media/FJIi9A1XsAIrfzY.jpg')._content))
detector = fer.FER()
detector.detect_emotions(img)
# Out:
# ---------------------------------------------------------------------------
# InvalidImage                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5408/980634142.py in <module>
#       4 # img = Image.open(io.BytesIO(requests.get('https://pbs.twimg.com/media/FJIi9A1XsAIrfzY.jpg')._content))
#       5 detector = fer.FER()
# ----> 6 detector.detect_emotions(img)
#
# c:\Users\QbaSo\bootcamp_env\lib\site-packages\fer\fer.py in detect_emotions(self, img, face_rectangles)
#     201         """
#     202         if img is None or not hasattr(img, "shape"):
# --> 203             raise InvalidImage("Image not valid.")
#     204
#     205         emotion_labels = self._get_labels()
#
# InvalidImage: Image not valid.

# %%
Image.open(io.BytesIO(requests.get('https://pbs.twimg.com/media/FJIi9A1XsAIrfzY.jpg')._content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=590x463 at 0x1724EA5CE50>

# %%
emotion, score = detector.top_emotion(img)
print(emotion, score)
